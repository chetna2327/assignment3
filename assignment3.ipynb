# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# -It makes program concise
# -We can do the function calls to reuse code contained in it over and over again.
# -It make code more organised

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# function in a code run when it is called.

# %% [markdown]
# 3. What statement creates a function?

# %% [markdown]
# Using Def Keyword we create a function.
# E.g.-Def Cls():
#        print("this is online class")

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# We can define the function using Def keyword however while calling a function we need to use the function name with parethesis containing parameters of that particular function

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# -A variable created outside of a function is global and can be used by anyone:
#     x = 300
#
# def myfunc():
#   print(x)
#
# myfunc()
#
# print(x)

# %% [markdown]
# -A variable created inside a function belongs to the local scope of that function, and can only be used inside that function.
# def myfunc():
#   x = 300
#   print(x)
#
# myfunc()

# %%
6. What happens to variables in a local scope when the function call returns?
# Out:
# Object `returns` not found.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns

# %%
def myfunc():
  x = 300
  return x

myfunc()
# Out:
# 300

# %% [markdown]
# It will return the local variable as output

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# A return statement is used to end the execution of the function call and “returns” the result (value of the expression following the return keyword) to the caller.
# Note: Return statement can not be used outside the function.
# A return value is the value that a function call evaluates to. Like any value, a return value can be used as part of an expression.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#    - If the return statement is without any expression, then the special value None is returned.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
# here x is global variable that function is refering to
# A global statement will force a variable in a function to refer to the global variable.

# %%
x = 300

def myfunc():
  print(x)

myfunc()
# Out:
# 300

# %% [markdown]
# 10. What is the data type of None?
#  - None itself is a Nonetype datatype it refers no value at all.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#    - it will import the module name areallyourpetsnamederic.

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#   - can be called as spam.bacon().

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# -Place the line of code that might cause an error in a try clause.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# The code that could potentially cause an error goes in the try clause.
#
# The code that executes if an error happens goes in the except clause.
